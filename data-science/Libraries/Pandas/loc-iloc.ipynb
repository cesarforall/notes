# %%
import pandas as pd

# %%
df_books = pd.read_csv('./bestsellers-with-categories.csv')
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books[0:4]
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
# 3                   1984 (Signet Classics)       George Orwell          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction
# 3    21424      6  2017      Fiction

# %% [markdown]
# ## Challenge
# - Importar un archivo .csv y cambiar los títulos a español.
# - Buscar las 10 primeras filas saltando de 2 en 2 y filtrar por los 2 primeros header
# - Buscar las 30 primeras filas filtrando por los headers 3 y 5

# %%
pd_csv = pd.read_csv('./bestsellers-with-categories.csv', header=0, names=['Nombre', 'Autor', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'])
type(pd_csv)
pd_csv
# Out:
#                                                 Nombre  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# La función .loc[] accede a datos de un dataframe especificando las etiquetas de columnas y filas

# %%
pd_csv.loc[0:11:2, ['Autor', 'Nombre']]
# Out:
#                        Autor  \
# 0                   JJ Smith
# 2         Jordan B. Peterson
# 4   National Geographic Kids
# 6        George R. R. Martin
# 8                James Comey
# 10           Fredrik Backman
#
#                                                Nombre
# 0                       10-Day Green Smoothie Cleanse
# 2             12 Rules for Life: An Antidote to Chaos
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 10                          A Man Called Ove: A Novel

# %% [markdown]
# La función .iloc[] accede a datos de un dataframe especificando los índices de columnas y filas

# %%
pd_csv.iloc[0:30:3, 0:3]
# Out:
#                                                Nombre  \
# 0                       10-Day Green Smoothie Cleanse
# 3                              1984 (Signet Classics)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 9                           A Man Called Ove: A Novel
# 12                            A Stolen Life: A Memoir
# 15  Adult Coloring Book Designs: Stress Relief Col...
# 18  Adult Coloring Books: A Coloring Book for Adul...
# 21                        All the Light We Cannot See
# 24                           And the Mountains Echoed
# 27                Autobiography of Mark Twain, Vol. 1
#
#                           Autor  User Rating
# 0                      JJ Smith          4.7
# 3                 George Orwell          4.7
# 6           George R. R. Martin          4.7
# 9               Fredrik Backman          4.6
# 12                Jaycee Dugard          4.6
# 15  Adult Coloring Book Designs          4.5
# 18    Coloring Books for Adults          4.5
# ...

# %%
pd_csv[['Autor', 'User Rating']]
# Out:
#                         Autor  User Rating
# 0                    JJ Smith          4.7
# 1                Stephen King          4.6
# 2          Jordan B. Peterson          4.7
# 3               George Orwell          4.7
# 4    National Geographic Kids          4.8
# ..                        ...          ...
# 545               Jeff Kinney          4.9
# 546               Jen Sincero          4.7
# 547               Jen Sincero          4.7
# 548               Jen Sincero          4.7
# 549               Jen Sincero          4.7
#
# [550 rows x 2 columns]
